# %% [raw]
# from jax.random import split, normal, uniform
# from jax.nn import softmax, sigmoid, relu, leaky_relu
#
# from jax_morph.utils import logistic

# %% [raw]
# ### divrate

# %% [raw]
# #@eqx.filter_jit
# def div_nn(params,
#            train_params,
#            n_hidden=3,
#            use_state_fields=CellState(*tuple([False]*3+[True]*2+[False]*2)),
#            train=True,
#           ):
#
#     assert type(n_hidden) == np.int_ or type(n_hidden) == int
#
#
#     def _div_nn(in_fields):
#         mlp = hk.nets.MLP([n_hidden,1],
#                           activation=jax.nn.leaky_relu,
#                           activate_final=False
#                          )
#         out = jax.nn.sigmoid(mlp(in_fields))
#         return out
#
#     _div_nn = hk.without_apply_rng(hk.transform(_div_nn))
#
#
#
#     def init(state, key):
#
#
#         in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#
#         input_dim = in_fields.shape[1]
#
#         p = _div_nn.init(key, np.zeros(input_dim))
#
#         #set trainability flag
#         train_p = jax.tree_map(lambda x: train, p)
#
#         #add to param dict
#         params['div_fn'] = p
#         train_params['div_fn'] = train_p
#
#
#         return params, train_params
#
#
#
#     def fwd(state, params):
#
#         in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#
#         x = _div_nn.apply(params['div_fn'], in_fields).flatten()
#
#         divrate = x*logistic(state.radius+.06, 50, params['cellRad'])
#
#         divrate = np.where(state.celltype==0.,0,divrate)
#
#         return divrate
#
#
#     return init, fwd

# %% [raw]
# ### secretion

# %% [raw]
# def sec_nn(params,
#            train_params,
#            n_hidden=3,
#            use_state_fields=CellState(*tuple([False]*3+[True]*2+[False]*2)),
#            train=True,
#           ):
#
#     assert type(n_hidden) == np.int_ or type(n_hidden) == int
#
#     def _sec_nn(in_fields):
#         mlp = hk.nets.MLP([n_hidden,params['n_chem']],
#                           activation=jax.nn.leaky_relu,
#                           activate_final=False
#                          )
#         out = jax.nn.sigmoid(mlp(in_fields))
#         return out
#
#     _sec_nn = hk.without_apply_rng(hk.transform(_sec_nn))
#
#
#
#     def init(state, key):
#
#
#         in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#
#         input_dim = in_fields.shape[1]
#
#         p = _sec_nn.init(key, np.zeros(input_dim))
#
#         #set trainability flag
#         train_p = jax.tree_map(lambda x: train, p)
#
#         #add to param dict
#         params['sec_fn'] = p
#         train_params['sec_fn'] = train_p
#
#         return params, train_params
#
#
#
#     def fwd(state, params):
#
#         in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#
#         sec = _sec_nn.apply(params['sec_fn'], in_fields)#.flatten()
#         sec = sec*params['sec_max']
#
#
#         #mask secretions based on which ct secretes what
#         ctype_sec_chem = params['ctype_sec_chem']
#
#         @vmap
#         def sec_mask(ct):
#             return ctype_sec_chem[np.int16(ct-1)] #change if we switch to dead cells = -1
#
#         mask = sec_mask(state.celltype)
#
#         return sec*mask
#
#
#     return init, fwd

# %% [markdown]
# # Imports

# %%
#no warnings about floating precision
import warnings
warnings.filterwarnings('ignore')

# %%
# LIMIT GPU MEMORY TAKEN UP BY THE NOTEBOOK
# you can specify the fraction of the AVAILABLE GPU memory that will be
# pre-allocated (jax default is .9)

import os
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '.95'
#os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'

#use another GPU if the default one is occupied
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import jax
import jax.numpy as np

from jax.random import split, PRNGKey
from jax import lax

jax.config.update('jax_debug_nans', True)

### NOTE: f32 gives > 3x speedup wrt f64
#config.update('jax_enable_x64', True)

#use this line to set the device to be used for the computations
#print(jax.devices())
#DOES NOT RECOGNIZE THE OPTION NAME FTM
#jax.config.update('jax_default_device', jax.devices()[1])

import equinox as eqx

import haiku as hk

from functools import partial

# %%
from jax_md import space

# %%
import jax_morph

from jax_morph.visualization import draw_circles_ctype, draw_circles_chem, draw_circles_divrate

from jax_morph.datastructures import CellState, SpaceFunc
from jax_morph.simulation import simulation, sim_trajectory

from jax_morph.cell_division import S_cell_division
from jax_morph.cell_growth import S_grow_cells

from chem_twotypes.mechanical import S_mechmin_twotypes
from chem_twotypes.secdiff import S_ss_chemfield, sec_nn
from chem_twotypes.divrates import S_set_divrate, div_nn

from chem_twotypes.initial_states import init_state_grow

# %%
import matplotlib.pyplot as plt

from tqdm import tqdm

# %% [markdown]
# # Set Parameters

# %%
ParamsDict = dict

# %%
# Define parameters -- blue particles are type 1, orange are type 2
# keep jax type casting to place vars in gpu memory

# Number of chemical signals
n_chem = 2
n_celltype = 2

#-------------------------------------------------------------------------------
### NEW CLEAN VERSION

#rows are ctypes, cols are chemicals
#1 if ct secretes chem, 0 otw
#needs to be array for indexing

ctype_sec_chem = np.identity(n_chem, dtype=np.int16) #each ct secretes one chem
#ctype_sec_chem = np.ones((n_celltype,n_chem), dtype=np.int16) #every ct secretes everything
#ctype_sec_chem = np.hstack([np.identity(2)]*1)


### CELL DIMENSIONS

#change constants in divrate calculation if cellRad != .5 
# always use python scalars
cellRad = .5
cellRadBirth = float(cellRad / np.sqrt(2))


### DIFFUSION

#possibly different diffusion and degradation for each chemical
diffCoeff = np.ones(n_chem) #np.linspace(1.,n_chem/2+2,n_chem) # #np.array([1.,3.])
degRate = np.ones(n_chem) #np.array([1.,1.])

#diffusion cutoff
r_cutoffDiff = 5.*cellRad
r_onsetDiff = r_cutoffDiff - .5


### SECRETION

# sec rate that gives concentration 1 at source at SS
sec_max_unitary = 2*np.sqrt(diffCoeff*degRate)

sec_max = sec_max_unitary*np.ones((n_chem,), dtype=np.float32)
#sec_max = sec_max.at[0].set(20.)
#sec_max = sec_max.at[1].set(2.)


sec_gamma = .5* np.ones((n_chem,n_chem), dtype=np.float32) #was 0.01
sec_k = 1.*np.ones((n_chem,n_chem), dtype=np.float32) 


# # DIVISION

div_gamma = 2.*np.ones(n_chem, dtype=np.float32)
div_k = 1.*np.ones(n_chem, dtype=np.float32)
# div_k = div_k.at[0].set(3.)


# MORSE POTENTIAL
# always use python scalars
alpha = 3.
eps_TwoTwo = 3. #orange
eps_OneOne = 3. #blue
eps_OneTwo = 3. 

#morse cutoff
r_cutoff = 4.*cellRad
r_onset = r_cutoff - .2


# number of gradient descent steps for potential minimization
mech_relaxation_steps = 50


# Initialization and number of added cells. 
ncells_init = 10 #number of cells in the initial cluster
n_ones_init = 5 #number of type-1 cell in the initail cluster
ncells_add = 100
#ncells_tot =  np.int16(ncells_init+ncells_add)# final number of cells

assert ncells_init > n_ones_init

# %%
#equinox automatically treats as static all non-array values
#cast floats/ints into arrays if the parameter needs a gradient

def _maybe_array(name, value, train_params):
    if train_params[name]:
        return np.array(value)
    else:
        return value

# %%
train_params = {
    'n_chem': False,
    #'secreted_by_ctypes': False,
    'ctype_sec_chem': False,
    
    'sec_max': False,
    'sec_gamma': False,
    'sec_k' : False,
    
    'div_gamma' : False,
    'div_k' : False,
    
    'cellRad' : False,
    'cellRadBirth' : False,
    
    'diffCoeff' : False,
    'degRate' : False,
    'r_onsetDiff' : False,
    'r_cutoffDiff' : False,
    
    'alpha': False, 
    'eps_TwoTwo': False, 
    'eps_OneOne' : False,
    'eps_OneTwo' : False,
    'r_onset' : False,
    'r_cutoff' : False,
    'mech_relaxation_steps' : False,
    
    'ncells_init' : False,
    'n_ones_init': False, 
    #'ncells_tot': ncells_tot,
    'ncells_add': False,
}

# %%
params = {
    'n_chem': n_chem,
    #'secreted_by_ctypes': sec_by_ctypes,
    'ctype_sec_chem': ctype_sec_chem,
    
    'sec_max': sec_max,
    'sec_gamma': sec_gamma,
    'sec_k' : sec_k,
    
    'div_gamma' : div_gamma,
    'div_k' : div_k,
    
    'cellRad' : cellRad,
    'cellRadBirth' : cellRadBirth,
    
    'diffCoeff' : diffCoeff,
    'degRate' : degRate,
    'r_onsetDiff' : r_onsetDiff,
    'r_cutoffDiff' : r_cutoffDiff,
    
    'alpha': _maybe_array('alpha', alpha, train_params), 
    'eps_TwoTwo': _maybe_array('eps_TwoTwo', eps_TwoTwo, train_params), 
    'eps_OneOne' : _maybe_array('eps_OneOne', eps_OneOne, train_params),
    'eps_OneTwo' : _maybe_array('eps_OneTwo', eps_OneTwo, train_params),
    'r_onset' : r_onset,
    'r_cutoff' : r_cutoff,
    'mech_relaxation_steps' : mech_relaxation_steps,
    
    'ncells_init' : ncells_init,
    'n_ones_init': n_ones_init, 
    #'ncells_tot': ncells_tot,
    'ncells_add': ncells_add,
}



p, hp = eqx.partition(params, train_params)

# %% [markdown]
# # Simulation

# %%
key = PRNGKey(0)

# %% [markdown]
# ## Generate initial state

# %%
# build initial state and space handling functions

fspace = SpaceFunc(*space.free())

key, init_key = split(key)

# generate initial state by growing from single cell
istate = init_state_grow(init_key, params, fspace)

# %% [markdown]
# ## Generate init-apply functions

# %%
# init division nn
DIV_HIDDEN = 3

div_init, div_nn_apply = div_nn(params,train_params,DIV_HIDDEN,train=True)

params, train_params = div_init(istate, key)

# %%
#init secretion nn
SEC_HIDDEN = 5

sec_init, sec_nn_apply = sec_nn(params,train_params,SEC_HIDDEN,train=False)

params, train_params = sec_init(istate, key)

# %%
# functions in this list will be executed in the given order
# at each simulation step

fstep = [
    S_cell_division,
    partial(S_grow_cells, grate=.05),
    S_mechmin_twotypes,
    partial(S_ss_chemfield, sec_fn=sec_nn_apply),
    partial(S_set_divrate, divrate_fn=eqx.filter_jit(div_nn_apply))
]


sim_init, sim_step = simulation(fstep, params, fspace)

# %% [markdown]
# # Optimization

# %%
from jax import vmap, value_and_grad

import optax
from optax import adam, sgd

from jax_morph.losses import reinforce_loss, avg_loss, simple_loss
from jax_morph.state_metrics import diff_n_ctypes

# %% [markdown]
# ## Optimization loop

# %%
EPOCHS = 30
EPISODES_PER_UPDATE = 128 #32

LEARNING_RATE = .05

p, hp = eqx.partition(params, train_params)

rloss = partial(reinforce_loss, metric_fn=partial(diff_n_ctypes, relative=True))
sloss = partial(simple_loss, metric_fn=partial(diff_n_ctypes, relative=True))



# init optimizer
optimizer = optax.adam(LEARNING_RATE)
opt_state = optimizer.init(p)


#--------------------------------------------
#store loss at initial params and calc grad 

key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
batch_subkeys = np.array(batch_subkeys)


ll, grads = value_and_grad(avg_loss)(p, hp, rloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

l = avg_loss(p, hp, sloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

#store initial params and loss
loss_t = [float(l)]
#params_t = [p]
#rloss_t = [float(ll)]


#--------------------------------------------


for t in tqdm(range(EPOCHS), total=EPOCHS):
    
    #generate batch of random keys
    key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
    batch_subkeys = np.array(batch_subkeys)
    
    # sgd step
    updates, opt_state = optimizer.update(grads, opt_state, p)

    p = eqx.apply_updates(p, updates)
    
    # surrogate loss and grads
    ll, grads = value_and_grad(avg_loss)(p, hp, rloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)
    
    #estimate actual avg loss
    l = avg_loss(p, hp, sloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)
    
    #store
    loss_t.append(float(l))
    #rloss_t.append(float(ll))
    #params_t.append(p)
# Out:
# 100%|████████████████████████████████████████████████| 30/30 [02:19<00:00,  4.66s/it]

# %%
#plt.hlines(AVG_EQ_PARAMS, 0, EPOCHS, colors='k', linestyles='--')
#plt.axhspan(ymin=AVG_EQ_PARAMS-STD_EQ_PARAMS, ymax=AVG_EQ_PARAMS-STD_EQ_PARAMS, fc='k')

plt.plot(np.sqrt(np.array(loss_t)), 'r')
#plt.yscale('log')

plt.grid(alpha=.2)


plt.xlabel('Epochs')
plt.ylabel('Loss');

# %% [markdown]
# ## Initial params

# %%
pp = params.copy()

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, pp, fspace)
fstate, _ = sim_trajectory(istate, sim_init, sim_step, ncells_add=100, key=subkey)


print(diff_n_ctypes(fstate, relative=True))
print(diff_n_ctypes(fstate))
# Out:
# 0.14545454
# 16

# %%
plt.hist(fstate.divrate[fstate.celltype==1].tolist(),20,density=True);
plt.hist(fstate.divrate[fstate.celltype==2].tolist(),20,density=True);

# %%
plt.hist(fstate.chemical[:,0].tolist(),density=True);
plt.hist(fstate.chemical[:,1].tolist(),density=True);

# %%
plt.plot(fstate.chemical[:,0].tolist(), fstate.divrate.tolist(),'.', label='Chem 0')
plt.plot(fstate.chemical[:,1].tolist(), fstate.divrate.tolist(),'.', label='Chem 1')

plt.ylabel('divrate')
plt.xlabel('chemical conc.')

plt.legend();

# %%
draw_circles_ctype(fstate);

# %%
draw_circles_divrate(fstate);

# %% [markdown]
# ## Trained params

# %%
# merge params dicts
all_params = eqx.combine(p, hp)

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, all_params, fspace)
fstate, _ = sim_trajectory(istate, sim_init, sim_step, ncells_add=300, key=subkey)



print(diff_n_ctypes(fstate, relative=True))
print(diff_n_ctypes(fstate))
# Out:
# 0.3612903
# 112

# %%
plt.hist(fstate.divrate[fstate.celltype==1].tolist(),20,density=True);
plt.hist(fstate.divrate[fstate.celltype==2].tolist(),20,density=True);

# %%
plt.hist(fstate.chemical[:,0].tolist(),density=True);
plt.hist(fstate.chemical[:,1].tolist(),density=True);

# %%
plt.plot(fstate.chemical[:,0].tolist(), fstate.divrate.tolist(),'.', label='Chem 0')
plt.plot(fstate.chemical[:,1].tolist(), fstate.divrate.tolist(),'.', label='Chem 1')

plt.ylabel('divrate')
plt.ylabel('chemical conc.')

plt.legend();

# %%
draw_circles_ctype(fstate);

# %%
draw_circles_divrate(fstate);

# %%
draw_circles_chem(fstate);

# %%
draw_circles_chem(fstate,1);

# %% [markdown]
# ## More chem

# %%
pp = params.copy()

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, pp, fspace)
fstate, _ = sim_trajectory(istate, sim_init, sim_step, ncells_add=200, key=subkey)

# %%
draw_circles_ctype(fstate);

print(diff_n_ctypes(fstate, relative=True))
# Out:
# 0.9333334

# %% [raw]
# draw_circles_chem(fstate,4);

# %%
draw_circles_divrate(fstate);

# %% [markdown]
# ## Different hidden sizes

# %%
#@eqx.filter_jit
def optimize(params,
             train_params,
             istate,
             key,
             EPOCHS = 10,
             EPISODES_PER_UPDATE = 128, #32
             LEARNING_RATE = .1,
             DIV_N = 3,
             SEC_N = 5,
             train_div=True,
             train_sec=False,
        ):

    key, subkey = split(key)
    div_init, div_nn_apply = div_nn(params,train_params,DIV_N,train=train_div)
    params, train_params = div_init(istate, subkey)

    #init secretion nn
    key, subkey = split(key)
    sec_init, sec_nn_apply = sec_nn(params,train_params,SEC_N,train=train_sec)
    params, train_params = sec_init(istate, subkey)
    
    fstep = [
        S_cell_division,
        partial(S_grow_cells, grate=.05),
        S_mechmin_twotypes,
        partial(S_ss_chemfield, sec_fn=sec_nn_apply),
        partial(S_set_divrate, divrate_fn=div_nn_apply)
    ]


    sim_init, sim_step = simulation(fstep, params, fspace)


    p, hp = eqx.partition(params, train_params)

    # init optimizer
    optimizer = optax.adam(LEARNING_RATE)
    opt_state = optimizer.init(p)


    #--------------------------------------------
    #store loss at initial params and calc grad 

    key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
    batch_subkeys = np.array(batch_subkeys)


    ll, grads = value_and_grad(avg_loss)(p, hp, reinforce_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

    l = avg_loss(p, hp, simple_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

    #store initial params and loss
    #params_t = [p]
    #loss_t = [float(l)]
    #rloss_t = [float(ll)]


    #--------------------------------------------

    loss_t = np.zeros(EPOCHS+1)
    loss_t = loss_t.at[0].set(l)

    for t in tqdm(np.arange(EPOCHS), total=EPOCHS):

        #generate batch of random keys
        key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
        batch_subkeys = np.array(batch_subkeys)

        # sgd step
        updates, opt_state = optimizer.update(grads, opt_state, p)

        p = eqx.apply_updates(p, updates)

        # surrogate loss and grads
        ll, grads = value_and_grad(avg_loss)(p, hp, reinforce_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

        #estimate actual avg loss
        l = avg_loss(p, hp, simple_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

        #store
        #loss_t.append(float(l))
        #rloss_t.append(float(ll))
        #params_t.append(p)
        loss_t = loss_t.at[t+1].set(l)
    
    return np.sqrt(loss_t), p

# %%
@eqx.filter_jit
def optimize(params,
             train_params,
             istate,
             key,
             EPOCHS = 10,
             EPISODES_PER_UPDATE = 128, #32
             LEARNING_RATE = .1,
             DIV_N = 3,
             SEC_N = 5,
             train_div=True,
             train_sec=False,
        ):

    key, subkey = split(key)
    div_init, div_nn_apply = div_nn(params,train_params,DIV_N,train=train_div)
    params, train_params = div_init(istate, subkey)

    #init secretion nn
    key, subkey = split(key)
    sec_init, sec_nn_apply = sec_nn(params,train_params,SEC_N,train=train_sec)
    params, train_params = sec_init(istate, subkey)
    
    fstep = [
        S_cell_division,
        partial(S_grow_cells, grate=.05),
        S_mechmin_twotypes,
        partial(S_ss_chemfield, sec_fn=sec_nn_apply),
        partial(S_set_divrate, divrate_fn=div_nn_apply)
    ]


    sim_init, sim_step = simulation(fstep, params, fspace)


    p, hp = eqx.partition(params, train_params)

    # init optimizer
    optimizer = optax.adam(LEARNING_RATE)
    opt_state = optimizer.init(p)


    #--------------------------------------------
    #store loss at initial params and calc grad 

    key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
    batch_subkeys = np.array(batch_subkeys)


    ll, grads = value_and_grad(avg_loss)(p, hp, reinforce_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

    l = avg_loss(p, hp, simple_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

    #store initial params and loss
    #params_t = [p]
    #loss_t = [float(l)]
    #rloss_t = [float(ll)]


    #--------------------------------------------

    loss_t = np.zeros(EPOCHS+1)
    loss_t = loss_t.at[0].set(l)

    for t in np.arange(EPOCHS):

        #generate batch of random keys
        key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
        batch_subkeys = np.array(batch_subkeys)

        # sgd step
        updates, opt_state = optimizer.update(grads, opt_state, p)

        p = eqx.apply_updates(p, updates)

        # surrogate loss and grads
        ll, grads = value_and_grad(avg_loss)(p, hp, reinforce_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

        #estimate actual avg loss
        l = avg_loss(p, hp, simple_loss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)

        #store
        #loss_t.append(float(l))
        #rloss_t.append(float(ll))
        #params_t.append(p)
        loss_t = loss_t.at[t+1].set(l)
    
    return np.sqrt(loss_t), p

# %%
div_ns = [2,3]#,5,10]

loss_n = {}
pp_n = {}

for DIV_N in div_ns:
    
    print(f'Training with {DIV_N} neurons...')
    
    key, subkey = split(key)

    lt,pp = optimize(params, train_params, istate, subkey, 10, DIV_N=DIV_N, SEC_N=7)
    
    loss_n[DIV_N] = lt.tolist()
    pp_n[DIV_N] = pp
# Out:
# Training with 2 neurons...
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File ~/.conda/envs/jax/lib/python3.10/runpy.py:191, in _run_module_as_main(***failed resolving arguments***)
#     190 except _Error as exc:
# --> 191     msg = "%s: %s" % (sys.executable, exc)
#     192     sys.exit(msg)
#
# File ~/.conda/envs/jax/lib/python3.10/runpy.py:75, in _run_code(***failed resolving arguments***)
#      74 loader = mod_spec.loader
# ---> 75 fname = mod_spec.origin
#      76 cached = mod_spec.cached
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel_launcher.py:12, in <module>
#       9 if __name__ == '__main__':
#      10     # Remove the CWD from sys.path while we load stuff.
#      11     # This is added back by InteractiveShellApp.init_path()
# ---> 12     if sys.path[0] == '':
#      13         del sys.path[0]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/traitlets/config/application.py:844, in Application.launch_instance(***failed resolving arguments***)
#     840 """Launch a global instance of this Application
#     841
#     842 If a global instance already exists, this reinitializes and starts it
#     843 """
# --> 844 app = cls.instance(**kwargs)
#     845 app.initialize(argv)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/kernelapp.py:668, in IPKernelApp.start(***failed resolving arguments***)
#     667 if self.trio_loop:
# --> 668     from ipykernel.trio_runner import TrioRunner
#     669     tr = TrioRunner()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/tornado/platform/asyncio.py:195, in BaseAsyncIOLoop.start(***failed resolving arguments***)
#     194 except (RuntimeError, AssertionError):
# --> 195     old_loop = None  # type: ignore
#     196 try:
#
# File ~/.conda/envs/jax/lib/python3.10/asyncio/base_events.py:594, in BaseEventLoop.run_forever(***failed resolving arguments***)
#     592 self._thread_id = threading.get_ident()
# --> 594 old_agen_hooks = sys.get_asyncgen_hooks()
#     595 sys.set_asyncgen_hooks(firstiter=self._asyncgen_firstiter_hook,
#     596                        finalizer=self._asyncgen_finalizer_hook)
#
# File ~/.conda/envs/jax/lib/python3.10/asyncio/base_events.py:1860, in BaseEventLoop._run_once(***failed resolving arguments***)
#    1858     timeout = min(max(0, when - self.time()), MAXIMUM_SELECT_TIMEOUT)
# -> 1860 event_list = self._selector.select(timeout)
#    1861 self._process_events(event_list)
#
# File ~/.conda/envs/jax/lib/python3.10/asyncio/events.py:80, in Handle._run(***failed resolving arguments***)
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/kernelbase.py:471, in Kernel.dispatch_queue(***failed resolving arguments***)
#     470 try:
# --> 471     await self.process_one()
#     472 except Exception:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/kernelbase.py:457, in Kernel.process_one(***failed resolving arguments***)
#     456 try:
# --> 457     t, dispatch, args = self.msg_queue.get_nowait()
#     458 except (asyncio.QueueEmpty, QueueEmpty):
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/kernelbase.py:344, in Kernel.dispatch_shell(***failed resolving arguments***)
#     343     self.shell_stream.flush(zmq.POLLOUT)
# --> 344     return
#     346 # Print some info about this message and leave a '--->' marker, so it's
#     347 # easier to trace visually the message chain when debugging.  Each
#     348 # handler prints its message at the end.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/kernelbase.py:644, in Kernel.execute_request(***failed resolving arguments***)
#     643 self.log.error("Got bad msg: ")
# --> 644 self.log.error("%s", parent)
#     645 return
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/ipkernel.py:329, in IPythonKernel.do_execute(***failed resolving arguments***)
#     327     preprocessing_exc_tuple = sys.exc_info()
# --> 329 if (
#     330     _asyncio_runner
#     331     and shell.loop_runner is _asyncio_runner
#     332     and asyncio.get_event_loop().is_running()
#     333     and should_run_async(
#     334         code,
#     335         transformed_cell=transformed_cell,
#     336         preprocessing_exc_tuple=preprocessing_exc_tuple,
#     337     )
#     338 ):
#     339     coro = run_cell(
#     340         code,
#     341         store_history=store_history,
#    (...)
#     344         preprocessing_exc_tuple=preprocessing_exc_tuple
#     345     )
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/ipykernel/zmqshell.py:532, in ZMQInteractiveShell.run_cell(***failed resolving arguments***)
#     531 self._last_traceback = None
# --> 532 return super().run_cell(*args, **kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2881, in InteractiveShell.run_cell(***failed resolving arguments***)
#    2879 try:
#    2880     result = self._run_cell(
# -> 2881         raw_cell, store_history, silent, shell_futures, cell_id
#    2882     )
#    2883 finally:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2910, in InteractiveShell._run_cell(***failed resolving arguments***)
#    2908 assert transformed_cell is not None
#    2909 coro = self.run_cell_async(
# -> 2910     raw_cell,
#    2911     store_history=store_history,
#    2912     silent=silent,
#    2913     shell_futures=shell_futures,
#    2914     transformed_cell=transformed_cell,
#    2915     preprocessing_exc_tuple=preprocessing_exc_tuple,
#    2916     cell_id=cell_id,
#    2917 )
#    2919 # run_cell_async is async, but may not actually need an eventloop.
#    2920 # when this is the case, we want to run it using the pseudo_sync_runner
#    2921 # so that code can invoke eventloops (for example via the %run , and
#    2922 # `%paste` magic.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner(***failed resolving arguments***)
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3108, in InteractiveShell.run_cell_async(***failed resolving arguments***)
#    3107     code_ast = compiler.ast_parse(cell, filename=cell_name)
# -> 3108 except self.custom_exceptions as e:
#    3109     etype, value, tb = sys.exc_info()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3305, in InteractiveShell.run_ast_nodes(***failed resolving arguments***)
#    3304     to_run_exec, to_run_interactive = nodelist[:-1], nodelist[-1:]
# -> 3305 elif interactivity == 'all':
#    3306     to_run_exec, to_run_interactive = [], nodelist
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3394, in InteractiveShell.run_code(***failed resolving arguments***)
#    3393 try:
# -> 3394     if async_:
#    3395         await eval(code_obj, self.user_global_ns, self.user_ns)
#
# Input In [34], in <cell line: 6>()
#       8 print(f'Training with {DIV_N} neurons...')
# ---> 10 key, subkey = split(key)
#      12 lt,pp = optimize(params, train_params, istate, subkey, 10, DIV_N=DIV_N, SEC_N=7)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:95, in _JitWrapper.__call__(***failed resolving arguments***)
#      94 def __call__(__self, *args, **kwargs):
# ---> 95     return __self._fun_wrapper(False, args, kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:71, in _JitWrapper._fun_wrapper(***failed resolving arguments***)
#      68 filter_args = filter_args + (self._filter_default,) * (
#      69     len(args) - len(filter_args)
#      70 )
# ---> 71 filter_kwargs = {
#      72     key: filter_kwargs.get(key, self._filter_default) for key in kwargs
#      73 }
#      74 filter_spec = (filter_args, filter_kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:34, in _filter_jit_cache.<locals>.fun_wrapped(***failed resolving arguments***)
#      27 (
#      28     static_fun_treedef,
#      29     static_fun_leaves,
#    (...)
#      32     filter_out,
#      33 ) = static
# ---> 34 fun = hashable_combine(dynamic_fun, static_fun_leaves, static_fun_treedef)
#      35 args, kwargs = hashable_combine(
#      36     dynamic_spec, static_spec_leaves, static_spec_treedef
#      37 )
#
# Input In [33], in optimize(***failed resolving arguments***)
#      15 key, subkey = split(key)
# ---> 16 div_init, div_nn_apply = div_nn(params,train_params,DIV_N,train=train_div)
#      17 params, train_params = div_init(istate, subkey)
#
# File ~/Projects/growing_clusters/github/jax-morph/Francesco/chem_twotypes/divrates.py:53, in div_nn.<locals>.init(***failed resolving arguments***)
#      50 def init(state, key):
# ---> 53     in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#      55     input_dim = in_fields.shape[1]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/transform.py:114, in without_state.<locals>.init_fn(***failed resolving arguments***)
#     113 def init_fn(*args, **kwargs):
# --> 114   params, state = f.init(*args, **kwargs)
#     115   if state:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/transform.py:336, in transform_with_state.<locals>.init_fn(***failed resolving arguments***)
#     335 rng = to_prng_sequence(rng, err_msg=INIT_RNG_ERROR)
# --> 336 with base.new_context(rng=rng) as ctx:
#     337   try:
#
# File ~/Projects/growing_clusters/github/jax-morph/Francesco/chem_twotypes/divrates.py:41, in div_nn.<locals>._div_nn(***failed resolving arguments***)
#      38 def _div_nn(in_fields):
#      39     mlp = hk.nets.MLP([n_hidden,1],
#      40                       activation=jax.nn.leaky_relu,
# ---> 41                       activate_final=False
#      42                      )
#      43     out = jax.nn.sigmoid(mlp(in_fields))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:418, in wrap_method.<locals>.wrapped(***failed resolving arguments***)
#     417 module_name = getattr(self, "module_name", None)
# --> 418 f = functools.partial(unbound_method, self)
#     419 f = functools.partial(run_interceptors, f, method_name, self)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:272, in run_interceptors(***failed resolving arguments***)
#     271 if not interceptor_stack:
# --> 272   return bound_method(*args, **kwargs)
#     274 ctx = MethodContext(module=self,
#     275                     method_name=method_name,
#     276                     orig_method=bound_method)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/nets/mlp.py:108, in MLP.__call__(***failed resolving arguments***)
#     106   raise ValueError("RNG should only be passed when using dropout.")
# --> 108 rng = hk.PRNGSequence(rng) if rng is not None else None
#     109 num_layers = len(self.layers)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:418, in wrap_method.<locals>.wrapped(***failed resolving arguments***)
#     417 module_name = getattr(self, "module_name", None)
# --> 418 f = functools.partial(unbound_method, self)
#     419 f = functools.partial(run_interceptors, f, method_name, self)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:272, in run_interceptors(***failed resolving arguments***)
#     271 if not interceptor_stack:
# --> 272   return bound_method(*args, **kwargs)
#     274 ctx = MethodContext(module=self,
#     275                     method_name=method_name,
#     276                     orig_method=bound_method)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/basic.py:173, in Linear.__call__(***failed resolving arguments***)
#     172 w_init = self.w_init
# --> 173 if w_init is None:
#     174   stddev = 1. / np.sqrt(self.input_size)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448, in replaceable.<locals>.wrapped(***failed resolving arguments***)
#     446 @functools.wraps(f)
#     447 def wrapped(*args, **kwargs):
# --> 448   return wrapped._current(*args, **kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:502, in get_parameter(***failed resolving arguments***)
#     501 fq_name = bundle_name + "/" + name
# --> 502 context = GetterContext(full_name=fq_name, module=current_module(),
#     503                         original_dtype=dtype, original_shape=shape,
#     504                         original_init=init)
#     506 if bundle_name not in frame.params:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/initializers.py:110, in TruncatedNormal.__call__(***failed resolving arguments***)
#     109 m = jax.lax.convert_element_type(self.mean, dtype)
# --> 110 s = jax.lax.convert_element_type(self.stddev, real_dtype)
#     111 is_complex = jnp.issubdtype(dtype, jnp.complexfloating)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448, in replaceable.<locals>.wrapped(***failed resolving arguments***)
#     446 @functools.wraps(f)
#     447 def wrapped(*args, **kwargs):
# --> 448   return wrapped._current(*args, **kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:964, in next_rng_key()
#     963 assert_context("next_rng_key")
# --> 964 assert_jax_usage("next_rng_key")
#     965 return next_rng_key_internal()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:1003, in next_rng_key_internal()
#    1002 def next_rng_key_internal() -> PRNGKey:
# -> 1003   rng_seq = rng_seq_or_fail()
#    1004   return next(rng_seq)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:910, in PRNGSequence.__next__(***failed resolving arguments***)
#     909 if not self._subkeys:
# --> 910   self.reserve(config.get_config().rng_reserve_size)
#     911 return self._subkeys.popleft()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883, in PRNGSequence.reserve(***failed resolving arguments***)
#     874 if num > 0:
#     875   # When storing keys we adopt a pattern of key0 being reserved for future
#     876   # splitting and all other keys being provided to the user in linear order.
#    (...)
#     881   #
#     882   # Where subkey1->subkey4 are provided to the user in order when requested.
# --> 883   new_keys = tuple(jax.random.split(self._key, num + 1))
#     884   self._key = new_keys[0]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/random.py:193, in split(***failed resolving arguments***)
#     183 """Splits a PRNG key into `num` new keys by adding a leading axis.
#     184
#     185 Args:
#    (...)
#     191   An array-like object of `num` new PRNG keys.
#     192 """
# --> 193 key, wrapped = _check_prng_key(key)
#     194 return _return_prng_keys(wrapped, _split(key, num))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/random.py:180, in _split(***failed resolving arguments***)
#     177 def _split(key: KeyArray, num: int = 2) -> KeyArray:
#     178   # Alternative to split() to use within random samplers.
#     179   # TODO(frostig): remove and use split() once we always enable_custom_prng
# --> 180   return key._split(num)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:199, in PRNGKeyArray._split(***failed resolving arguments***)
#     198 def _split(self, num: int) -> 'PRNGKeyArray':
# --> 199   return PRNGKeyArray(self.impl, self.impl.split(self._keys, num))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:457, in threefry_split(***failed resolving arguments***)
#     456 def threefry_split(key: jnp.ndarray, num: int) -> jnp.ndarray:
# --> 457   return _threefry_split(key, int(num))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:461, in _threefry_split(***failed resolving arguments***)
#     459 @partial(jit, static_argnums=(1,), inline=True)
#     460 def _threefry_split(key, num) -> jnp.ndarray:
# --> 461   counts = lax.iota(np.uint32, num * 2)
#     462   return lax.reshape(threefry_2x32(key, counts), (num, 2))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:433, in threefry_2x32(***failed resolving arguments***)
#     424 """Apply the Threefry 2x32 hash.
#     425
#     426 Args:
#    (...)
#     431   An array of dtype uint32 with the same shape as `count`.
#     432 """
# --> 433 key1, key2 = keypair
#     434 if not lax.dtype(key1) == lax.dtype(key2) == lax.dtype(count) == np.uint32:
#
# JaxStackTraceBeforeTransformation: jax._src.errors.UnexpectedTracerError: Encountered an unexpected tracer. A function transformed by JAX had a side effect, allowing for a reference to an intermediate value with shape (2,) and dtype uint32 to escape.
# JAX transformations require that functions explicitly return their outputs, and disallow saving intermediate values to global state.
# The function being traced when the value leaked was optimize at /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:25 traced for jit.
# ------------------------------
# The leaked intermediate value was created on line /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883 (reserve).
# ------------------------------
# When the value was created, the final 5 stack frames (most recent last) excluding JAX-internal frames were:
# ------------------------------
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448 (wrapped)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:964 (next_rng_key)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:1003 (next_rng_key_internal)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:910 (__next__)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883 (reserve)
# ------------------------------
#
# To catch the leak earlier, try setting the environment variable JAX_CHECK_TRACER_LEAKS or using the `jax.checking_leaks` context manager.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.UnexpectedTracerError
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# UnexpectedTracerError                     Traceback (most recent call last)
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/transform.py:338, in transform_with_state.<locals>.init_fn(rng, *args, **kwargs)
#     337 try:
# --> 338   f(*args, **kwargs)
#     339 except jax.errors.UnexpectedTracerError as e:
#
# File ~/Projects/growing_clusters/github/jax-morph/Francesco/chem_twotypes/divrates.py:43, in div_nn.<locals>._div_nn(in_fields)
#      39 mlp = hk.nets.MLP([n_hidden,1],
#      40                   activation=jax.nn.leaky_relu,
#      41                   activate_final=False
#      42                  )
# ---> 43 out = jax.nn.sigmoid(mlp(in_fields))
#      44 return out
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:426, in wrap_method.<locals>.wrapped(self, *args, **kwargs)
#     424     f = jax.named_call(f, name=method_name)
# --> 426 out = f(*args, **kwargs)
#     428 # Module names are set in the constructor. If `f` is the constructor then
#     429 # its name will only be set **after** `f` has run. For methods other
#     430 # than `__init__` we need the name before running in order to wrap their
#     431 # execution with `named_call`.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/api.py:3121, in named_call.<locals>.named_call_f(*args, **kwargs)
#    3120 flat_f, out_tree = flatten_fun_nokwargs(lu_f, in_tree)
# -> 3121 out_flat = core.named_call_p.bind(flat_f, name=name)
#    3122 return tree_unflatten(out_tree(), out_flat)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1796, in CallPrimitive.bind(self, fun, *args, **params)
#    1795 def bind(self, fun, *args, **params):
# -> 1796   return call_bind(self, fun, *args, **params)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1812, in call_bind(primitive, fun, *args, **params)
#    1811 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1812 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1813 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1544, in DynamicJaxprTrace.process_call(self, call_primitive, f, explicit_tracers, params)
#    1543 with core.new_sublevel():
# -> 1544   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1545     f, self.main, in_avals, keep_inputs=keep_inputs)
#    1546 if jaxpr.effects:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1826, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    1825 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1826 ans = fun.call_wrapped(*in_tracers_)
#    1827 out_tracers = map(trace.full_raise, ans)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/linear_util.py:168, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     167 try:
# --> 168   ans = self.f(*args, **dict(self.params, **kwargs))
#     169 except:
#     170   # Some transformations yield from inside context managers, so we have to
#     171   # interrupt them before reraising the exception. Otherwise they will only
#     172   # get garbage-collected at some later time, running their cleanup tasks
#     173   # only after this exception is handled, which can corrupt the global
#     174   # state.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/api.py:3119, in named_call.<locals>.named_call_f.<locals>.<lambda>()
#    3117 @functools.wraps(fun)
#    3118 def named_call_f(*args, **kwargs):
# -> 3119   lu_f = lu.wrap_init(lambda: fun(*args, **kwargs))
#    3120   flat_f, out_tree = flatten_fun_nokwargs(lu_f, in_tree)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:272, in run_interceptors(bound_method, method_name, self, *args, **kwargs)
#     271 if not interceptor_stack:
# --> 272   return bound_method(*args, **kwargs)
#     274 ctx = MethodContext(module=self,
#     275                     method_name=method_name,
#     276                     orig_method=bound_method)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/nets/mlp.py:113, in MLP.__call__(self, inputs, dropout_rate, rng)
#     112 for i, layer in enumerate(self.layers):
# --> 113   out = layer(out)
#     114   if i < (num_layers - 1) or self.activate_final:
#     115     # Only perform dropout if we are activating the output.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:426, in wrap_method.<locals>.wrapped(self, *args, **kwargs)
#     424     f = jax.named_call(f, name=method_name)
# --> 426 out = f(*args, **kwargs)
#     428 # Module names are set in the constructor. If `f` is the constructor then
#     429 # its name will only be set **after** `f` has run. For methods other
#     430 # than `__init__` we need the name before running in order to wrap their
#     431 # execution with `named_call`.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/api.py:3121, in named_call.<locals>.named_call_f(*args, **kwargs)
#    3120 flat_f, out_tree = flatten_fun_nokwargs(lu_f, in_tree)
# -> 3121 out_flat = core.named_call_p.bind(flat_f, name=name)
#    3122 return tree_unflatten(out_tree(), out_flat)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1796, in CallPrimitive.bind(self, fun, *args, **params)
#    1795 def bind(self, fun, *args, **params):
# -> 1796   return call_bind(self, fun, *args, **params)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1812, in call_bind(primitive, fun, *args, **params)
#    1811 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1812 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1813 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1544, in DynamicJaxprTrace.process_call(self, call_primitive, f, explicit_tracers, params)
#    1543 with core.new_sublevel():
# -> 1544   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    1545     f, self.main, in_avals, keep_inputs=keep_inputs)
#    1546 if jaxpr.effects:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1826, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    1825 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1826 ans = fun.call_wrapped(*in_tracers_)
#    1827 out_tracers = map(trace.full_raise, ans)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/linear_util.py:168, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     167 try:
# --> 168   ans = self.f(*args, **dict(self.params, **kwargs))
#     169 except:
#     170   # Some transformations yield from inside context managers, so we have to
#     171   # interrupt them before reraising the exception. Otherwise they will only
#     172   # get garbage-collected at some later time, running their cleanup tasks
#     173   # only after this exception is handled, which can corrupt the global
#     174   # state.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/api.py:3119, in named_call.<locals>.named_call_f.<locals>.<lambda>()
#    3117 @functools.wraps(fun)
#    3118 def named_call_f(*args, **kwargs):
# -> 3119   lu_f = lu.wrap_init(lambda: fun(*args, **kwargs))
#    3120   flat_f, out_tree = flatten_fun_nokwargs(lu_f, in_tree)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/module.py:272, in run_interceptors(bound_method, method_name, self, *args, **kwargs)
#     271 if not interceptor_stack:
# --> 272   return bound_method(*args, **kwargs)
#     274 ctx = MethodContext(module=self,
#     275                     method_name=method_name,
#     276                     orig_method=bound_method)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/basic.py:176, in Linear.__call__(self, inputs, precision)
#     175   w_init = hk.initializers.TruncatedNormal(stddev=stddev)
# --> 176 w = hk.get_parameter("w", [input_size, output_size], dtype, init=w_init)
#     178 out = jnp.dot(inputs, w, precision=precision)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448, in replaceable.<locals>.wrapped(*args, **kwargs)
#     446 @functools.wraps(f)
#     447 def wrapped(*args, **kwargs):
# --> 448   return wrapped._current(*args, **kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:515, in get_parameter(name, shape, dtype, init)
#     514 else:
# --> 515   param = init(shape, dtype)
#     517 if param is DO_NOT_STORE:
#     518   # Initializers or custom creators that return `DO_NOT_STORE` are required
#     519   # to produce a value for the parameter via a custom getter.
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/initializers.py:114, in TruncatedNormal.__call__(self, shape, dtype)
#     113   shape = [2, *shape]
# --> 114 unscaled = jax.random.truncated_normal(hk.next_rng_key(), -2., 2., shape,
#     115                                        real_dtype)
#     116 if is_complex:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448, in replaceable.<locals>.wrapped(*args, **kwargs)
#     446 @functools.wraps(f)
#     447 def wrapped(*args, **kwargs):
# --> 448   return wrapped._current(*args, **kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:965, in next_rng_key()
#     964 assert_jax_usage("next_rng_key")
# --> 965 return next_rng_key_internal()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:1004, in next_rng_key_internal()
#    1003 rng_seq = rng_seq_or_fail()
# -> 1004 return next(rng_seq)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:910, in PRNGSequence.__next__(self)
#     909 if not self._subkeys:
# --> 910   self.reserve(config.get_config().rng_reserve_size)
#     911 return self._subkeys.popleft()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883, in PRNGSequence.reserve(self, num)
#     874 if num > 0:
#     875   # When storing keys we adopt a pattern of key0 being reserved for future
#     876   # splitting and all other keys being provided to the user in linear order.
#    (...)
#     881   #
#     882   # Where subkey1->subkey4 are provided to the user in order when requested.
# --> 883   new_keys = tuple(jax.random.split(self._key, num + 1))
#     884   self._key = new_keys[0]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/random.py:194, in split(key, num)
#     193 key, wrapped = _check_prng_key(key)
# --> 194 return _return_prng_keys(wrapped, _split(key, num))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/random.py:180, in _split(key, num)
#     177 def _split(key: KeyArray, num: int = 2) -> KeyArray:
#     178   # Alternative to split() to use within random samplers.
#     179   # TODO(frostig): remove and use split() once we always enable_custom_prng
# --> 180   return key._split(num)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:199, in PRNGKeyArray._split(self, num)
#     198 def _split(self, num: int) -> 'PRNGKeyArray':
# --> 199   return PRNGKeyArray(self.impl, self.impl.split(self._keys, num))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/prng.py:457, in threefry_split(key, num)
#     456 def threefry_split(key: jnp.ndarray, num: int) -> jnp.ndarray:
# --> 457   return _threefry_split(key, int(num))
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/api.py:465, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     464   flat_fun = lu.annotate(flat_fun, in_type)
# --> 465 out_flat = xla.xla_call(
#     466     flat_fun, *args_flat,
#     467     device=device, backend=backend, name=flat_fun.__name__,
#     468     donated_invars=donated_invars, inline=inline)
#     469 out_pytree_def = out_tree()
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1796, in CallPrimitive.bind(self, fun, *args, **params)
#    1795 def bind(self, fun, *args, **params):
# -> 1796   return call_bind(self, fun, *args, **params)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:1812, in call_bind(primitive, fun, *args, **params)
#    1811 fun_ = lu.annotate(fun_, fun.in_type)
# -> 1812 outs = top_trace.process_call(primitive, fun_, tracers, params)
#    1813 return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1550, in DynamicJaxprTrace.process_call(self, call_primitive, f, explicit_tracers, params)
#    1549 if params.get('inline', False):
# -> 1550   return core.eval_jaxpr(jaxpr, consts, *tracers)
#    1551 env = {v: t for v, t in zip(jaxpr.constvars, consts) if isinstance(t, Tracer)}
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:393, in eval_jaxpr(jaxpr, consts, *args)
#     392 with source_info_util.user_context(eqn.source_info.traceback, name_stack=name_stack):
# --> 393   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     394 if eqn.primitive.multiple_results:
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:325, in Primitive.bind(self, *args, **params)
#     323 assert (not config.jax_enable_checks or
#     324         all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 325 return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/core.py:328, in Primitive.bind_with_trace(self, trace, args, params)
#     327 def bind_with_trace(self, trace, args, params):
# --> 328   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     329   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1521, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1520   return custom_staging_rules[primitive](self, *tracers, **params)
# -> 1521 return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1529, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1528 out_tracers = [DynamicJaxprTracer(self, a, source_info) for a in out_avals]
# -> 1529 invars = map(self.getvar, tracers)
#    1530 outvars = map(self.makevar, out_tracers)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/_src/util.py:47, in safe_map(f, *args)
#      46   assert len(arg) == n, 'length mismatch: {}'.format(list(map(len, args)))
# ---> 47 return list(map(f, *args))
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1501, in DynamicJaxprTrace.getvar(self, tracer)
#    1500 if var is None:
# -> 1501   raise core.escaped_tracer_error(tracer)
#    1502 return var
#
# UnexpectedTracerError: Encountered an unexpected tracer. A function transformed by JAX had a side effect, allowing for a reference to an intermediate value with shape (2,) and dtype uint32 to escape.
# JAX transformations require that functions explicitly return their outputs, and disallow saving intermediate values to global state.
# The function being traced when the value leaked was optimize at /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:25 traced for jit.
# ------------------------------
# The leaked intermediate value was created on line /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883 (reserve).
# ------------------------------
# When the value was created, the final 5 stack frames (most recent last) excluding JAX-internal frames were:
# ------------------------------
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:448 (wrapped)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:964 (next_rng_key)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:1003 (next_rng_key_internal)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:910 (__next__)
# /home/fmottes/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/base.py:883 (reserve)
# ------------------------------
#
# To catch the leak earlier, try setting the environment variable JAX_CHECK_TRACER_LEAKS or using the `jax.checking_leaks` context manager.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.UnexpectedTracerError
#
# The above exception was the direct cause of the following exception:
#
# UnexpectedTracerError                     Traceback (most recent call last)
# Input In [34], in <cell line: 6>()
#       8 print(f'Training with {DIV_N} neurons...')
#      10 key, subkey = split(key)
# ---> 12 lt,pp = optimize(params, train_params, istate, subkey, 10, DIV_N=DIV_N, SEC_N=7)
#      14 loss_n[DIV_N] = lt.tolist()
#      15 pp_n[DIV_N] = pp
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:95, in _JitWrapper.__call__(_JitWrapper__self, *args, **kwargs)
#      94 def __call__(__self, *args, **kwargs):
# ---> 95     return __self._fun_wrapper(False, args, kwargs)
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:91, in _JitWrapper._fun_wrapper(self, is_lower, args, kwargs)
#      89     return self._cached.lower(dynamic, static)
#      90 else:
# ---> 91     dynamic_out, static_out = self._cached(dynamic, static)
#      92     return combine(dynamic_out, static_out.value)
#
#     [... skipping hidden 14 frame]
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/equinox/jit.py:38, in _filter_jit_cache.<locals>.fun_wrapped(dynamic, static)
#      34 fun = hashable_combine(dynamic_fun, static_fun_leaves, static_fun_treedef)
#      35 args, kwargs = hashable_combine(
#      36     dynamic_spec, static_spec_leaves, static_spec_treedef
#      37 )
# ---> 38 out = fun(*args, **kwargs)
#      39 dynamic_out, static_out = partition(out, filter_out)
#      40 return dynamic_out, Static(static_out)
#
# Input In [33], in optimize(params, train_params, istate, key, EPOCHS, EPISODES_PER_UPDATE, LEARNING_RATE, DIV_N, SEC_N, train_div, train_sec)
#      15 key, subkey = split(key)
#      16 div_init, div_nn_apply = div_nn(params,train_params,DIV_N,train=train_div)
# ---> 17 params, train_params = div_init(istate, subkey)
#      19 #init secretion nn
#      20 key, subkey = split(key)
#
# File ~/Projects/growing_clusters/github/jax-morph/Francesco/chem_twotypes/divrates.py:57, in div_nn.<locals>.init(state, key)
#      53 in_fields = np.hstack([f if len(f.shape)>1 else f[:,np.newaxis] for f in jax.tree_leaves(eqx.filter(state, use_state_fields))])
#      55 input_dim = in_fields.shape[1]
# ---> 57 p = _div_nn.init(key, np.zeros(input_dim))
#      59 #add to param dict
#      60 params['div_fn'] = p
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/transform.py:114, in without_state.<locals>.init_fn(*args, **kwargs)
#     113 def init_fn(*args, **kwargs):
# --> 114   params, state = f.init(*args, **kwargs)
#     115   if state:
#     116     raise ValueError("If your transformed function uses `hk.{get,set}_state` "
#     117                      "then use `hk.transform_with_state`.")
#
# File ~/.conda/envs/jax/lib/python3.10/site-packages/haiku/_src/transform.py:340, in transform_with_state.<locals>.init_fn(rng, *args, **kwargs)
#     338     f(*args, **kwargs)
#     339   except jax.errors.UnexpectedTracerError as e:
# --> 340     raise jax.errors.UnexpectedTracerError(unexpected_tracer_hint) from e
#     341 return ctx.collect_params(), ctx.collect_initial_state()
#
# UnexpectedTracerError: An UnexpectedTracerError was raised while inside a Haiku transformed function (see error above).
# Hint: are you using a JAX transform or JAX control-flow function (jax.vmap/jax.scan/...) inside a Haiku transform? You might want to use the Haiku version of the transform instead (hk.vmap/hk.scan/...).
# See https://dm-haiku.readthedocs.io/en/latest/notebooks/transforms.html on why you can't use JAX transforms inside a Haiku module.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.UnexpectedTracerError

# %%
for n in loss_n:
    plt.plot(loss_n[n], label=str(n))
    
    
plt.xlabel('epochs')
plt.ylabel('Loss')

    
plt.grid(alpha=.2)
plt.legend(title='Hidden\nNeurons');

# %%
p, hp = eqx.partition(params, train_params)


for n in pp_n:
    
    key, subkey = split(key)

    div_init, div_nn = div_nn_chem(params,train_params,n)

    params, train_params = div_init(istate, subkey)
    
    ppp, hpp = eqx.partition(params, train_params)
    
    key, *subkeys = split(key, 301)
    subkeys = np.array(subkeys)

    lss = simple_loss(ppp, hpp, fstep, fspace, istate, subkeys)

    plt.hist(np.sqrt(lss).tolist(), alpha=.3, label=str(n), density=True)
    
    
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       4 for n in pp_n:
#       6     key, subkey = split(key)
# ----> 8     div_init, div_nn = div_nn_chem(params,train_params,n)
#      10     params, train_params = div_init(istate, subkey)
#      12     ppp, hpp = eqx.partition(params, train_params)
#
# NameError: name 'div_nn_chem' is not defined

# %%
p, hp = eqx.partition(params, train_params)


for n in pp_n:
    
    key, *subkeys = split(key, 301)
    subkeys = np.array(subkeys)

    lss = simple_loss(pp_n[n], hp, fstep, fspace, istate, subkeys)

    plt.hist(np.sqrt(lss).tolist(), alpha=.3, label=str(n), density=True)
    
    
plt.legend();

# %%
fstate.divrate
# Out:
# DeviceArray([0.47893405, 0.479799  , 0.47960663, 0.47919053, 0.43481365,
#              0.48003292, 0.47829497, 0.4793114 , 0.4798279 , 0.47927994,
#              0.47924203, 0.33632067, 0.47972077, 0.47946215, 0.47810355,
#              0.47902876, 0.4799136 , 0.47954038, 0.47965986, 0.4784856 ,
#              0.47939584, 0.4793705 , 0.47854024, 0.47905976, 0.48427406,
#              0.47975993, 0.47982445, 0.47851464, 0.4799242 , 0.47895494,
#              0.47853887, 0.47889096, 0.4796374 , 0.4793157 , 0.47842255,
#              0.47998303, 0.47937834, 0.4795779 , 0.47886267, 0.47880346,
#              0.48004547, 0.479682  , 0.47809738, 0.48010644, 0.47996804,
#              0.47845185, 0.47914505, 0.49336907, 0.49982172, 0.47830904,
#              0.47827202, 0.47975034, 0.4797943 , 0.47976375, 0.47980496,
#              0.48009828, 0.4781177 , 0.47936374, 0.47895813, 0.47847086,
#              0.47961307, 0.47984284, 0.4793261 , 0.47989503, 0.4799767 ,
#              0.47918433, 0.4796948 , 0.47891623, 0.47934926, 0.47902018,
#              0.4796014 , 0.47849572, 0.47964564, 0.4794789 , 0.47890633,
#              0.47975504, 0.47886807, 0.47987077, 0.47918183, 0.4780444 ,
#              0.47969663, 0.47944233, 0.4797956 , 0.47829434, 0.47843048,
#              0.4798744 , 0.48926073, 0.4795649 , 0.4797253 , 0.4792218 ,
#              0.48605445, 0.47942364, 0.47905108, 0.47955757, 0.47858736,
#              0.4797521 , 0.47927204, 0.47959092, 0.49842405, 0.4793857 ,
#              0.47970596, 0.490547  , 0.4783975 , 0.47990376, 0.47930545,
#              0.47920215, 0.4785351 , 0.4788411 , 0.4793726 , 0.47828865,
#              0.47955832, 0.4787472 , 0.48003453, 0.47793517, 0.4795218 ,
#              0.47925133, 0.49358955, 0.47836712, 0.47838455, 0.47929886,
#              0.47991717, 0.49024782, 0.47904506, 0.47983903, 0.47982302,
#              0.49682504, 0.03943351, 0.4797106 , 0.47979146, 0.4796568 ,
#              0.47970656, 0.484518  , 0.4800129 , 0.49617267, 0.47951204,
#              0.47915435, 0.4790099 , 0.47957173, 0.50007075, 0.47938463,
#              0.4783996 , 0.4791623 , 0.47892013, 0.47939116, 0.47969937,
#              0.47915322, 0.47979805, 0.47878945, 0.4791494 , 0.47987163,
#              0.47979015, 0.09488052, 0.47969738, 0.47900808, 0.47909293,
#              0.4896726 , 0.4799062 , 0.47966006, 0.47947264, 0.479526  ,
#              0.4788868 , 0.47947207, 0.4791183 , 0.01602105, 0.478663  ,
#              0.500849  , 0.48009998, 0.4988383 , 0.47860417, 0.47936186,
#              0.48013574, 0.4785663 , 0.47925603, 0.47833362, 0.4799691 ,
#              0.47965524, 0.47939435, 0.47912636, 0.500617  , 0.47962877,
#              0.4796336 , 0.47895518, 0.47983307, 0.47953233, 0.47840357,
#              0.48000056, 0.48017412, 0.500764  , 0.4796628 , 0.20070192,
#              0.4793771 , 0.47868332, 0.47871324, 0.47962612, 0.47965303,
#              0.48591757, 0.4797561 , 0.4797847 , 0.4797706 , 0.47962162,
#              0.47956422, 0.47882828, 0.47962743, 0.4797214 , 0.43527403,
#              0.33630967, 0.20063283, 0.09488674, 0.03941845, 0.01602624],            dtype=float32)
