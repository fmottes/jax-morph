# %% [markdown]
# # Colab installs

# %%
# %%capture

# %pip install jax -U
# %pip install jax-md -U
# %pip install jaxlib -U
# %pip install dm-haiku
# %pip install optax
# %pip install equinox==0.7.1

# %%
# %%capture

# #Clone our git repo to be able to use the code
# !git clone https://gianthawk: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@github.com/fmottes/jax-morph.git

# %cd jax-morph
# !git checkout fdev
# !python setup.py install

# %% [markdown]
# # Imports

# %%
# LIMIT GPU MEMORY TAKEN UP BY THE NOTEBOOK
# you can specify the fraction of the AVAILABLE GPU memory that will be
# pre-allocated (jax default is .9)

import os
# os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '.9'
# #os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'

# #use another GPU if the default one is occupied
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#no warnings about floating precision
import warnings
warnings.filterwarnings('ignore')


########## IMPORT JAX ECOSYSTEM ##########
import jax
import jax.numpy as np
from jax.random import split, PRNGKey

jax.config.update('jax_debug_nans', True)


import equinox as eqx
import haiku as hk


import jax_md
import jax_md.dataclasses as jdc
from jax_md import space


########## IMPORT JAX-MORPH FUNCTIONS ##########
################################################

from jax_morph.datastructures import SpaceFunc
from jax_morph.utils import _maybe_array

from jax_morph.simulation import simulation, sim_trajectory

# IMPORT STATE-CHANGING FUNCTIONS
from jax_morph.division_and_growth.cell_division import S_cell_division, S_no_division
from jax_morph.division_and_growth.cell_growth import S_grow_cells

from jax_morph.mechanics.morse import S_mech_morse_relax
from jax_morph.chemicals.secdiff import S_ss_chemfield

from jax_morph.cell_internals.divrates import S_set_divrate, div_nn
from jax_morph.cell_internals.secretion import sec_nn
#from jax_morph.cell_internals.grad_estimate import S_chemical_gradients

from jax_morph.initial_states import init_state_grow

from jax_morph.visualization import draw_circles_ctype, draw_circles_chem, draw_circles_divrate


########## IMPORT PLOTTING UTILITIES ##########
###############################################
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})


########## IMPORT OTHER UTILITIES ##########
############################################
from tqdm import tqdm
from functools import partial

# %% [markdown]
# # Set Parameters

# %%
# Define parameters -- blue particles are type 1, orange are type 2


n_dim = 2
n_chem = 2 # Number of chemical signals
n_celltype = 1


### CELL DIMENSIONS

#change constants in divrate calculation if cellRad != .5 
# always use python scalars
cellRad = .5
cellRadBirth = float(cellRad / np.sqrt(2))


### DIFFUSION

#possibly different diffusion and degradation for each chemical
diffCoeff = np.ones(n_chem)
degRate = np.ones(n_chem)

#diffusion cutoff (for better performance)
r_cutoffDiff = 5.*cellRad
r_onsetDiff = r_cutoffDiff - .5


### SECRETION

# sec rate that gives concentration 1 at source at SS
#sec_max_unitary = 2*np.sqrt(diffCoeff*degRate)

sec_max = np.ones((n_chem,), dtype=np.float32)

# example - unbalanced secretion
#sec_max = sec_max.at[0].set(8.)


# SECRETION 

#rows are ctypes, cols are chemicals
#1 if ct secretes chem, 0 otw
#needs to be array for indexing

#ctype_sec_chem = np.identity(n_chem, dtype=np.int16) #each ct secretes one chem
ctype_sec_chem = np.ones((n_celltype,n_chem), dtype=np.int16) #every ct secretes everything


# MORSE POTENTIAL
# always use python scalars
alpha = 3.
epsilon = 3.


# eps_OneOne = 3. #blue
# eps_TwoTwo = 3. #orange
# eps_OneTwo = 3. 

#morse cutoff (for better performance)
r_cutoff = 5*cellRad
r_onset = r_cutoff - .2



# number of gradient descent steps for potential minimization
mech_relaxation_steps = 15


# Initialization and number of added cells. 
ncells_init = 4 #number of cells in the initial cluster
ncells_add = 116

# %%
train_params = {
    'n_dim':                    False,
    'n_chem':                   False,
    'ctype_sec_chem':           False,
    
    'sec_max':                      True,
    
    'cellRad' :                 False,
    'cellRadBirth' :            False,
    
    'diffCoeff' :                   True,
    'degRate' :                 False,
    'r_onsetDiff' :             False,
    'r_cutoffDiff' :            False,
    
    'alpha':                    False, 
    'epsilon':                  False,
    # 'eps_TwoTwo':               False, 
    # 'eps_OneOne' :              False,
    # 'eps_OneTwo' :              False,
    'r_onset' :                 False,
    'r_cutoff' :                False,
    'mech_relaxation_steps' :   False,
    
    'ncells_init' :             False,
    'ncells_add':               False,
}

# %%
params = {
    'n_dim':                    n_dim,
    'n_chem':                   n_chem,
    'ctype_sec_chem':           ctype_sec_chem,
    
    'sec_max':                  sec_max,
    
    'cellRad' :                 cellRad,
    'cellRadBirth' :            cellRadBirth,
    
    'diffCoeff' :               diffCoeff,
    'degRate' :                 degRate,
    'r_onsetDiff' :             r_onsetDiff,
    'r_cutoffDiff' :            r_cutoffDiff,
    
    'alpha':                    _maybe_array('alpha', alpha, train_params),
    'epsilon':                  _maybe_array('epsilon', epsilon, train_params),
    # 'eps_TwoTwo':               _maybe_array('eps_TwoTwo', eps_TwoTwo, train_params), 
    # 'eps_OneOne' :              _maybe_array('eps_OneOne', eps_OneOne, train_params),
    # 'eps_OneTwo' :              _maybe_array('eps_OneTwo', eps_OneTwo, train_params),
    'r_onset' :                 r_onset,
    'r_cutoff' :                r_cutoff,
    'mech_relaxation_steps' :   mech_relaxation_steps,
    
    'ncells_init' :             ncells_init,
    'ncells_add':               ncells_add,
}

# %% [markdown]
# # State dataclass
#
# **Note:**
# - HYPERPARAMETERS:
# Shape parameters needed to correctly initialize the datastructures in the actual system state below. Needed to be able to initialize the system state.
#
# - STATE:
# All of the fields that are needed to keep track of the actual system state. Should be initialized automatically with the default values, given the shape parameters above.

# %%
# decorator MUST be jax_md.dataclass instead of dataclasses.dataclass
# to make dataclass compatible with jax tree operations
@jdc.dataclass
class CellState:
    '''
    Dataclass containing the system state.

    STATE
    -----
    position: jax_md.util.Array
        Positions of cells.
    celltype: jax_md.util.Array
        Cell types.
    radius: jax_md.util.Array
        Cell radii.
    chemical: jax_md.util.Array
        Chemical concentrations.
    chemgrad: jax_md.util.Array
        Chemical gradients.
    divrate: jax_md.util.Array
        Division rates.
    key: jax_md.util.Array
        Random number generator key.
    '''

    # STATE
    position:   jax_md.util.Array
    celltype:   jax_md.util.Array
    radius:     jax_md.util.Array
    chemical:   jax_md.util.Array
    #chemgrad:   jax_md.util.Array
    divrate:    jax_md.util.Array
    key:        jax_md.util.Array


    @classmethod
    def default_init(cls, n_dim=2, n_chem=1):
        '''
        Intializes a CellState with no cells (empty data structures, with correct shapes).
        

        Parameters
        ----------
        n_dim: int
            Number of spatial dimensions.
        n_chem: int
            Number of chemical species.

        Returns
        -------
        CellState
        '''

        assert n_dim == 2 or n_dim == 3, 'n_dim must be 2 or 3'
        assert n_chem > 0 and isinstance(n_chem, int), 'n_chem must be a positive integer'
        
        defaultstate = {
            'position'  :   np.empty(shape=(0, n_dim),              dtype=np.float32),
            'celltype'  :   np.empty(shape=(0,),                    dtype=np.int8),
            'radius'    :   np.empty(shape=(0,),                    dtype=np.float32),
            'chemical'  :   np.empty(shape=(0, n_chem),             dtype=np.float32),
            #'chemgrad'  :   np.empty(shape=(0, int(n_dim*n_chem)),  dtype=np.float32),
            'divrate'   :   np.empty(shape=(0,),                    dtype=np.float32),
            'key'       :   None,
        }


        return cls(**defaultstate)

# %% [markdown]
# # Simulation

# %%
key = PRNGKey(0)

# %% [markdown]
# ## Generate initial state

# %%
# build space handling function and initial state
box_size = 8.
fspace = SpaceFunc(*space.periodic(box_size))
#fspace = SpaceFunc(*space.free())

N_CELLS_INIT = params['ncells_init']



#generate empty data structure with correct shapes
istate = CellState.default_init(n_dim=params['n_dim'], n_chem=params['n_chem'])

# populate initial state by growing from single cell
key, init_key = split(key)
istate = init_state_grow(init_key, istate, params, fspace, N_CELLS_INIT)

# set half of the cells to type 2
#istate = jdc.replace(istate, celltype=istate.celltype.at[istate.celltype.shape[0]//2:].set(2))

# %%
draw_circles_ctype(istate);

# %% [markdown]
# ## Initialize ANNs

# %% [markdown]
# ### Division

# %%
#hidden neurons per layer
DIV_HIDDEN = [8]


#input fields to the network
use_state_fields = CellState(position=   False, 
                             celltype=   False, 
                             radius=     False, 
                             chemical=      True,
                            #chemgrad=   False,
                             divrate=    True, 
                             key=        False
                            )


# init nn functions
div_init, div_nn_apply = div_nn(params,
                                train_params,
                                DIV_HIDDEN,
                                use_state_fields,
                                train=True,
                                )


#initialize network parameters
key, init_key = split(key)
params, train_params = div_init(istate, init_key)

# %% [markdown]
# ### Secretion

# %%
#hidden neurons per layer
SEC_HIDDEN = [512,256,128]


#input fields to the network
use_state_fields = CellState(position=   False, 
                             celltype=   False, 
                             radius=     False, 
                             chemical=   True,
                            #chemgrad=   False,
                             divrate=    False, 
                             key=        False
                            )


# init nn functions
sec_init, sec_nn_apply = sec_nn(params,
                                train_params,
                                SEC_HIDDEN,
                                use_state_fields,
                                train=True)


#initialize network parameters
key, init_key = split(key)
params, train_params = sec_init(istate, init_key)

# %% [markdown]
# ## Simulation loop

# %%
# functions in this list will be executed in the given order
# at each simulation step


fstep = [
    # ENV CHANGES
    S_cell_division,
    #S_no_division,
    S_grow_cells,
    partial(S_mech_morse_relax, morse_eps_sigma='onetype'),
    partial(S_ss_chemfield, sec_fn=sec_nn_apply, n_iter=3),

    # SENSING
    #chemicals sensed directly
    #S_chemical_gradients,

    # INTERNAL (HIDDEN) STATE
    #no hidden state in this case

    # POLICIES
    partial(S_set_divrate, divrate_fn=eqx.filter_jit(div_nn_apply))
]


sim_init, sim_step = simulation(fstep, params, fspace)

# %% [markdown]
# # Example - (forward) simulation

# %%
fstate, _ = sim_trajectory(istate, sim_init, sim_step, 116, init_key)

# %%
draw_circles_ctype(fstate, grid=True);

# %%
fig, ax = draw_circles_chem(fstate)

# %%
fig, ax = draw_circles_chem(fstate,1)

# %% [markdown]
# # Optimization

# %%
import optax

from jax import value_and_grad

from jax_morph.optimization.losses import reinforce_loss, avg_loss

# %% [markdown]
# ## State metrics

# %%
def half_flag(state, box_size=8.):

    #filter = (state.position[:,0] < .6*box_size) & (state.position[:,0] > .4*box_size)

    alive = state.celltype > 0

    filter = (state.position[:,0] < 0.) #.5*box_size)

    return np.sum((np.where(filter, 1, .3)-state.chemical[:,0])**2 * alive)

# %% [markdown]
# ## Optimization loop

# %%
def train(key, 
          EPOCHS, 
          EPISODES_PER_UPDATE, 
          EPISODES_PER_EVAL, 
          LEARNING_RATE, 
          rloss, 
          sloss, 
          fstep, 
          fspace, 
          istate
          ):

    p, hp = eqx.partition(params, train_params)

    # init optimizer
    optimizer = optax.adam(LEARNING_RATE)
    opt_state = optimizer.init(p)


    #--------------------------------------------
    #store loss at initial params and calc grad 

    key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
    batch_subkeys = np.array(batch_subkeys)

    ll, grads = value_and_grad(avg_loss)(p, hp, rloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)


    key, *eval_subkeys = split(key, EPISODES_PER_EVAL+1)
    eval_subkeys = np.array(eval_subkeys)

    l = avg_loss(p, hp, sloss, eval_subkeys, fstep=fstep, fspace=fspace, istate=istate)

    #store initial params and loss
    loss_t = [float(l)]
    params_t = [p]
    grads_t = [grads]

    #--------------------------------------------

    pbar = tqdm(range(EPOCHS), total=EPOCHS)
    for t in pbar:
        #generate batch of random keys
        key, *batch_subkeys = split(key, EPISODES_PER_UPDATE+1)
        batch_subkeys = np.array(batch_subkeys)
    
        # sgd step
        updates, opt_state = optimizer.update(grads, opt_state, p)

        p = eqx.apply_updates(p, updates)
    
        #clip diffCoeff if trained
        if None != p['diffCoeff']:
            p['diffCoeff'] = np.clip(p['diffCoeff'],.2)
    
        #estimate actual avg loss
        key, *eval_subkeys = split(key, EPISODES_PER_EVAL+1)
        eval_subkeys = np.array(eval_subkeys)

        l = avg_loss(p, hp, sloss, eval_subkeys, fstep=fstep, fspace=fspace, istate=istate)
    
        # surrogate loss and grads
        ll, grads = value_and_grad(avg_loss)(p, hp, rloss, batch_subkeys, fstep=fstep, fspace=fspace, istate=istate)


        #store
        loss_t += [float(l)]
        params_t += [p]
        grads_t += [grads]
    
        # if 0 == t%5:
        #     print(float(l))

        pbar.set_description(f'Loss: {float(l):.3f}')


    return loss_t, params_t, grads_t

# %% [markdown]
# ## Run optimization

# %%
EPOCHS = 50
EPISODES_PER_UPDATE = 8
EPISODES_PER_EVAL = 32

LEARNING_RATE = 5e-4


############## define loss parameters
METRIC_FN = half_flag
TARGET_METRIC = 0.

LAMBDA = 0. #.01


rloss = partial(reinforce_loss, metric_fn=METRIC_FN, target_metric=TARGET_METRIC, REINFORCE=True, LAMBDA=LAMBDA)
sloss = partial(reinforce_loss, metric_fn=METRIC_FN, target_metric=TARGET_METRIC, REINFORCE=False)
##############

key, train_key = split(key)

loss_t, params_t, grads_t = train(train_key, 
                         EPOCHS, 
                         EPISODES_PER_UPDATE, 
                         EPISODES_PER_EVAL, 
                         LEARNING_RATE, 
                         rloss, 
                         sloss,
                         fstep,
                         fspace,
                         istate
                         )
# Out:
# Loss: 15.687: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:29<00:00,  1.78s/it]

# %%
#plt.plot(np.array(loss_t), 'r')
plt.plot(np.array(loss_t), 'r')

plt.grid(alpha=.2)


plt.xlabel('Training Steps')
plt.ylabel('Loss');

# %% [markdown]
# # sec_nn visualization
#
# **NOTE:** Only works right away if the input to the secretion NN are two chemical concentrations (otherwise needs tweaking).

# %%
#### div
def _sec_nn(in_fields):
    mlp = hk.nets.MLP(SEC_HIDDEN+[params['n_chem']],
                      activation=jax.nn.leaky_relu,
                      activate_final=False
                     )
    out = jax.nn.sigmoid(mlp(in_fields))
    return out

_sec_nn = hk.without_apply_rng(hk.transform(_sec_nn))

# %%
# create chem grid for plotting
xxx, yyy = np.meshgrid(np.linspace(0,10,30), np.linspace(0,10,30))

# %% [markdown]
# ### Before training

# %%
cc = np.vstack((xxx.flatten(),yyy.flatten()))

dd = _sec_nn.apply(params['sec_fn'], cc.T)#.flatten()


fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
surf = ax.plot_trisurf(cc[0], cc[1], dd[:,0], linewidth=.1, antialiased=True, shade=False, cmap=plt.cm.YlGn)
surf = ax.plot_trisurf(cc[0], cc[1], dd[:,1], linewidth=.1, antialiased=True, shade=False, cmap=plt.cm.BuPu)

ax.view_init(25, 220)

ax.set_xlabel('Chem. 0', labelpad=12)
ax.set_ylabel('Chem. 1', labelpad=12)
ax.set_zlabel('secretion', labelpad=15)

ax.set_title('Random');

# %% [markdown]
# ### After training

# %%
cc = np.vstack((xxx.flatten(),yyy.flatten()))

dd = _sec_nn.apply(params_t[-1]['sec_fn'], cc.T)#.flatten()

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
surf = ax.plot_trisurf(cc[0], cc[1], dd[:,0], linewidth=.1, antialiased=True, shade=False, cmap=plt.cm.YlGn)
surf = ax.plot_trisurf(cc[0], cc[1], dd[:,1], linewidth=.1, antialiased=True, shade=False, cmap=plt.cm.BuPu)

ax.view_init(25, 220)

ax.set_xlabel('Chem. 0', labelpad=12)
ax.set_ylabel('Chem. 1', labelpad=12)
ax.set_zlabel('secretion', labelpad=12)

ax.set_title('Trained');

# %% [markdown]
# # Analyze final states

# %% [markdown]
# ## Initial params

# %%
pp = params.copy()

NCELLS_ADD = params['ncells_add']

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, pp, fspace)
fstate, _ = sim_trajectory(istate, sim_init, sim_step, ncells_add=NCELLS_ADD, key=subkey)

print(METRIC_FN(fstate))
# Out:
# 555.14136

# %%
plt.hist(fstate.divrate.tolist(),20,density=True);
plt.xlabel('divrate');

# %%
for chem in fstate.chemical.T.tolist():
    plt.hist(chem, alpha=.5);

plt.xlabel('Chem. Conc.');

# %%
yy = fstate.divrate.tolist()

for chem in fstate.chemical.T.tolist():
    plt.plot(chem, yy, '.', alpha=.5)

plt.ylabel('divrate')
plt.xlabel('chemical conc.');

#plt.legend();

# %%
draw_circles_chem(fstate);

# %%
draw_circles_chem(fstate,1);

# %% [markdown]
# ## Trained params

# %%
# merge params dicts
all_params = eqx.combine(params_t[-1], params)

NCELLS_ADD = params['ncells_add']

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, all_params, fspace)
fstate, _ = sim_trajectory(istate, sim_init, sim_step, ncells_add=NCELLS_ADD, key=subkey)



print('Final state metric:\t' + str(METRIC_FN(fstate)))
# Out:
# Final state metric:	15.706902

# %%
plt.hist(fstate.divrate.tolist(),20,density=True);
plt.xlabel('divrate');

# %%
for chem in fstate.chemical.T.tolist():
    plt.hist(chem, alpha=.5);

plt.xlabel('Chem. Conc.');

# %%
yy = fstate.divrate.tolist()

for chem in fstate.chemical.T.tolist():
    plt.plot(chem, yy, '.', alpha=.5)

plt.ylabel('divrate')
plt.xlabel('chemical conc.');

#plt.legend();

# %%
draw_circles_divrate(fstate);

# %%
draw_circles_chem(fstate);

# %%
draw_circles_chem(fstate,1);

# %%
grads_t[-1]['sec_max']
# Out:
# Array([-13.88558, -27.62756], dtype=float32)

# %% [markdown]
# # Analyze dynamics

# %% [markdown]
# ## Initial params

# %%
# TRAINED PARAMS
all_params = params.copy()

# %%
NCELLS_ADD=int(2*all_params['ncells_add'])

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, all_params, fspace)
fstate, (state_t,_) = sim_trajectory(istate, sim_init, sim_step, ncells_add=NCELLS_ADD, key=subkey, history=True)

# list of CellState objects for each time step
st = [sim_init(istate,NCELLS_ADD,subkey)]+[CellState(*[f[i] for f in jdc.unpack(state_t)]) for i in range(NCELLS_ADD)]

# %%
#extract relevant statistics
avg_dr = {1:[], 2:[]}
metric_t = []
for s in tqdm(st):
    avg_dr[1] += [float(np.mean(s.divrate[s.celltype==1]))]
    avg_dr[2] += [float(np.mean(s.divrate[s.celltype==2]))]
    metric_t += [METRIC_FN(s)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 193/193 [01:17<00:00,  2.48it/s]

# %%
plt.plot(avg_dr[1], 'r', label='Cell type 1')
plt.plot(avg_dr[2], 'b', label='Cell type 2')
plt.axvline(all_params['ncells_add'], color='g', linestyle='--', label='Training simulation length')

plt.xlabel('Simulation steps')
plt.ylabel('Average division rate');

plt.title('Random parameters')

#legend with small font
plt.legend(fontsize=10);

# %%
plt.plot(metric_t, 'k')

#vertical line at NCELLS_ADD
plt.axvline(all_params['ncells_add'], color='g', linestyle='--', label='Training simulation length')

plt.xlabel('Simulation steps')
plt.ylabel('Cell type difference');

plt.title('Random parameters')


#legend with small font
plt.legend(fontsize=10);

# %% [markdown]
# ## Trained params

# %%
# TRAINED PARAMS
all_params = eqx.combine(params_t[-1], params)

# %%
NCELLS_ADD=int(2*all_params['ncells_add'])

key, subkey = split(key)

#forward pass - simulation
sim_init, sim_step = simulation(fstep, all_params, fspace)
fstate, (state_t,_) = sim_trajectory(istate, sim_init, sim_step, ncells_add=NCELLS_ADD, key=subkey, history=True)

# list of CellState objects for each time step
st = [sim_init(istate,NCELLS_ADD,subkey)]+[CellState(*[f[i] for f in jdc.unpack(state_t)]) for i in range(NCELLS_ADD)]

# %%
#extract relevant statistics
avg_dr = {1:[], 2:[]}
metric_t = []
for s in tqdm(st):
    avg_dr[1] += [float(np.mean(s.divrate[s.celltype==1]))]
    avg_dr[2] += [float(np.mean(s.divrate[s.celltype==2]))]
    metric_t += [METRIC_FN(s)]
# Out:
#   0%|                                                                                                                      | 0/193 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     313 with TraceAnnotation(name, **decorator_kwargs):
# --> 314   return func(*args, **kwargs)
#     315 return wrapper
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1920, in ExecuteReplicated.__call__(self, *args)
#    1919 for arrays in out_arrays:
# -> 1920   dispatch.check_special(self.name, arrays)
#    1921 return self.out_handler(out_arrays)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/dispatch.py:436, in check_special(name, bufs)
#     435 for buf in bufs:
# --> 436   _check_special(name, buf.dtype, buf)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/dispatch.py:441, in _check_special(name, dtype, buf)
#     440 if config.jax_debug_nans and np.any(np.isnan(np.asarray(buf))):
# --> 441   raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     442 if config.jax_debug_infs and np.any(np.isinf(np.asarray(buf))):
#
# FloatingPointError: invalid value (nan) encountered in jit(_mean)
#
# During handling of the above exception, another exception occurred:
#
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/runpy.py:196, in _run_module_as_main(***failed resolving arguments***)
#     195     sys.argv[0] = mod_spec.origin
# --> 196 return _run_code(code, main_globals, None,
#     197                  "__main__", mod_spec)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/runpy.py:86, in _run_code(***failed resolving arguments***)
#      79 run_globals.update(__name__ = mod_name,
#      80                    __file__ = fname,
#      81                    __cached__ = cached,
#    (...)
#      84                    __package__ = pkg_name,
#      85                    __spec__ = mod_spec)
# ---> 86 exec(code, run_globals)
#      87 return run_globals
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel_launcher.py:16, in <module>
#      15 from ipykernel import kernelapp as app
# ---> 16 app.launch_new_instance()
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/traitlets/config/application.py:846, in Application.launch_instance(***failed resolving arguments***)
#     845 app.initialize(argv)
# --> 846 app.start()
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/kernelapp.py:677, in IPKernelApp.start(***failed resolving arguments***)
#     676 try:
# --> 677     self.io_loop.start()
#     678 except KeyboardInterrupt:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/tornado/platform/asyncio.py:199, in BaseAsyncIOLoop.start(***failed resolving arguments***)
#     198     asyncio.set_event_loop(self.asyncio_loop)
# --> 199     self.asyncio_loop.run_forever()
#     200 finally:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/asyncio/base_events.py:600, in BaseEventLoop.run_forever(***failed resolving arguments***)
#     599 while True:
# --> 600     self._run_once()
#     601     if self._stopping:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/asyncio/base_events.py:1896, in BaseEventLoop._run_once(***failed resolving arguments***)
#    1895     else:
# -> 1896         handle._run()
#    1897 handle = None
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/asyncio/events.py:80, in Handle._run(***failed resolving arguments***)
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/kernelbase.py:471, in Kernel.dispatch_queue(***failed resolving arguments***)
#     470 try:
# --> 471     await self.process_one()
#     472 except Exception:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/kernelbase.py:460, in Kernel.process_one(***failed resolving arguments***)
#     459         return None
# --> 460 await dispatch(*args)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/kernelbase.py:367, in Kernel.dispatch_shell(***failed resolving arguments***)
#     366     if inspect.isawaitable(result):
# --> 367         await result
#     368 except Exception:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/kernelbase.py:662, in Kernel.execute_request(***failed resolving arguments***)
#     661 if inspect.isawaitable(reply_content):
# --> 662     reply_content = await reply_content
#     664 # Flush output before sending the reply.
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/ipkernel.py:360, in IPythonKernel.do_execute(***failed resolving arguments***)
#     356     else:
#     357         # runner isn't already running,
#     358         # make synchronous call,
#     359         # letting shell dispatch to loop runners
# --> 360         res = shell.run_cell(code, store_history=store_history, silent=silent)
#     361 finally:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/ipykernel/zmqshell.py:532, in ZMQInteractiveShell.run_cell(***failed resolving arguments***)
#     531 self._last_traceback = None
# --> 532 return super().run_cell(*args, **kwargs)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2880, in InteractiveShell.run_cell(***failed resolving arguments***)
#    2879 try:
# -> 2880     result = self._run_cell(
#    2881         raw_cell, store_history, silent, shell_futures, cell_id
#    2882     )
#    2883 finally:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2935, in InteractiveShell._run_cell(***failed resolving arguments***)
#    2934 try:
# -> 2935     return runner(coro)
#    2936 except BaseException as e:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner(***failed resolving arguments***)
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3134, in InteractiveShell.run_cell_async(***failed resolving arguments***)
#    3132 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3134 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3135        interactivity=interactivity, compiler=compiler, result=result)
#    3137 self.last_execution_succeeded = not has_raised
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3337, in InteractiveShell.run_ast_nodes(***failed resolving arguments***)
#    3336     asy = compare(code)
# -> 3337 if await self.run_code(code, result, async_=asy):
#    3338     return True
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3397, in InteractiveShell.run_code(***failed resolving arguments***)
#    3396     else:
# -> 3397         exec(code_obj, self.user_global_ns, self.user_ns)
#    3398 finally:
#    3399     # Reset our crash handler in place
#
# /home/fmottes/Projects/jax-morph/Francesco/TEST3 - French flag.ipynb Cell 79 in <cell line: 4>()
#       <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> avg_dr[1] += [float(np.mean(s.divrate[s.celltype==1]))]
# ----> <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> avg_dr[2] += [float(np.mean(s.divrate[s.celltype==2]))]
#       <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> metric_t += [METRIC_FN(s)]
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/numpy/reductions.py:323, in mean(***failed resolving arguments***)
#     319 @_wraps(np.mean, skip_params=['out'])
#     320 def mean(a: ArrayLike, axis: Axis = None, dtype: DTypeLike = None,
#     321          out: None = None, keepdims: bool = False, *,
#     322          where: Optional[ArrayLike] = None) -> Array:
# --> 323   return _mean(a, _ensure_optional_axes(axis), dtype, out, keepdims,
#     324                where=where)
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/numpy/reductions.py:347, in _mean(***failed resolving arguments***)
#     345   normalizer = sum(_broadcast_to(where, np.shape(a)), axis, dtype=dtype, keepdims=keepdims)
# --> 347 return lax.div(
#     348     sum(a, axis, dtype=dtype, keepdims=keepdims, where=where),
#     349     lax.convert_element_type(normalizer, dtype))
#
# JaxStackTraceBeforeTransformation: FloatingPointError: invalid value (nan) encountered in jit(div)
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# FloatingPointError                        Traceback (most recent call last)
# /home/fmottes/Projects/jax-morph/Francesco/TEST3 - French flag.ipynb Cell 79 in <cell line: 4>()
#       <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> for s in tqdm(st):
#       <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     avg_dr[1] += [float(np.mean(s.divrate[s.celltype==1]))]
# ----> <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     avg_dr[2] += [float(np.mean(s.divrate[s.celltype==2]))]
#       <a href='vscode-notebook-cell://tunnel%2Bhuginndbc/home/fmottes/Projects/jax-morph/Francesco/TEST3%20-%20French%20flag.ipynb#Y143sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     metric_t += [METRIC_FN(s)]
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/numpy/reductions.py:323, in mean(a, axis, dtype, out, keepdims, where)
#     319 @_wraps(np.mean, skip_params=['out'])
#     320 def mean(a: ArrayLike, axis: Axis = None, dtype: DTypeLike = None,
#     321          out: None = None, keepdims: bool = False, *,
#     322          where: Optional[ArrayLike] = None) -> Array:
# --> 323   return _mean(a, _ensure_optional_axes(axis), dtype, out, keepdims,
#     324                where=where)
#
#     [... skipping hidden 17 frame]
#
# File ~/Programs/anaconda3/envs/jax_newest/lib/python3.10/site-packages/jax/_src/dispatch.py:441, in _check_special(name, dtype, buf)
#     439 if dtypes.issubdtype(dtype, np.inexact):
#     440   if config.jax_debug_nans and np.any(np.isnan(np.asarray(buf))):
# --> 441     raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     442   if config.jax_debug_infs and np.any(np.isinf(np.asarray(buf))):
#     443     raise FloatingPointError(f"invalid value (inf) encountered in {name}")
#
# FloatingPointError: invalid value (nan) encountered in jit(div)

# %%
plt.plot(avg_dr[1], 'r', label='Cell type 1')
plt.plot(avg_dr[2], 'b', label='Cell type 2')
plt.axvline(all_params['ncells_add'], color='g', linestyle='--', label='Training simulation length')

plt.xlabel('Simulation steps')
plt.ylabel('Average division rate');

plt.title('Trained parameters')

#legend with small font
plt.legend(fontsize=10);

# %%
plt.plot(metric_t, 'k')

#vertical line at NCELLS_ADD
plt.axvline(all_params['ncells_add'], color='g', linestyle='--', label='Training simulation length')

plt.xlabel('Simulation steps')
plt.ylabel('Cell type difference');

plt.title('Trained parameters')


#legend with small font
plt.legend(fontsize=10);
